# %%
import tensorflow as tf
from IPython.display import Image, display

import matplotlib.pyplot as plt
import tensorflow_hub as hub

import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !wget https://storage.googleapis.com/ibeans/train.zip
# !wget https://storage.googleapis.com/ibeans/validation.zip
# !wget https://storage.googleapis.com/ibeans/test.zip
# Out:
# --2022-12-31 23:15:11--  https://storage.googleapis.com/ibeans/train.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.212.128, 172.217.214.128, 172.253.114.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143812152 (137M) [application/zip]
# Saving to: ‘train.zip’
#
# train.zip           100%[===================>] 137.15M  45.4MB/s    in 3.0s
#
# 2022-12-31 23:15:14 (45.4 MB/s) - ‘train.zip’ saved [143812152/143812152]
#
# --2022-12-31 23:15:14--  https://storage.googleapis.com/ibeans/validation.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.212.128, 172.217.214.128, 172.253.114.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18504213 (18M) [application/zip]
# Saving to: ‘validation.zip’
#
# validation.zip      100%[===================>]  17.65M  41.7MB/s    in 0.4s
#
# 2022-12-31 23:15:15 (41.7 MB/s) - ‘validation.zip’ saved [18504213/18504213]
#
# --2022-12-31 23:15:15--  https://storage.googleapis.com/ibeans/test.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.212.128, 172.217.214.128, 172.253.114.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17708541 (17M) [application/zip]
# Saving to: ‘test.zip’
#
# test.zip            100%[===================>]  16.89M  33.7MB/s    in 0.5s
#
# 2022-12-31 23:15:16 (33.7 MB/s) - ‘test.zip’ saved [17708541/17708541]

# %%
# !mkdir beans

# %%
# !unzip train.zip -d beans/
# !unzip test.zip -d beans/
# !unzip validation.zip -d beans/
# Out:
# Archive:  train.zip
#    creating: beans/train/
#    creating: beans/train/healthy/
#    creating: beans/train/angular_leaf_spot/
#    creating: beans/train/bean_rust/
#   inflating: beans/train/healthy/healthy_train.265.jpg
#   inflating: beans/train/healthy/healthy_train.271.jpg
#   inflating: beans/train/healthy/healthy_train.259.jpg
#   inflating: beans/train/healthy/healthy_train.99.jpg
#   inflating: beans/train/healthy/healthy_train.311.jpg
#   inflating: beans/train/healthy/healthy_train.66.jpg
#   inflating: beans/train/healthy/healthy_train.72.jpg
#   inflating: beans/train/healthy/healthy_train.305.jpg
#   inflating: beans/train/healthy/healthy_train.339.jpg
#   inflating: beans/train/healthy/healthy_train.113.jpg
#   inflating: beans/train/healthy/healthy_train.107.jpg
#   inflating: beans/train/healthy/healthy_train.106.jpg
#   inflating: beans/train/healthy/healthy_train.112.jpg
#   inflating: beans/train/healthy/healthy_train.338.jpg
#   inflating: beans/train/healthy/healthy_train.73.jpg
#   inflating: beans/train/healthy/healthy_train.304.jpg
#   inflating: beans/train/healthy/healthy_train.310.jpg
#   inflating: beans/train/healthy/healthy_train.67.jpg
#   inflating: beans/train/healthy/healthy_train.98.jpg
#   inflating: beans/train/healthy/healthy_train.258.jpg
#   inflating: beans/train/healthy/healthy_train.270.jpg
#   inflating: beans/train/healthy/healthy_train.264.jpg
#   inflating: beans/train/healthy/healthy_train.299.jpg
#   inflating: beans/train/healthy/healthy_train.272.jpg
#   inflating: beans/train/healthy/healthy_train.266.jpg
#   inflating: beans/train/healthy/healthy_train.306.jpg
#   inflating: beans/train/healthy/healthy_train.71.jpg
jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.42.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.41.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.40.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.5.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.21.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.35.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.34.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.20.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.4.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.6.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.36.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.22.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.23.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.37.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.7.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.3.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.33.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.27.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.26.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.32.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.2.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.0.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.24.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.30.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.18.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.19.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.31.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.25.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.1.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.28.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.14.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.15.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.29.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.17.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.16.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.12.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.13.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.9.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.11.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.39.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.38.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.10.jpg
#   inflating: beans/test/angular_leaf_spot/angular_leaf_spot_test.8.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.33.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.27.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.26.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.32.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.18.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.24.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.30.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.31.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.25.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.19.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.21.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.35.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.34.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.20.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.36.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.22.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.23.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.37.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.9.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.8.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.42.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.41.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.40.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.0.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.1.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.3.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.2.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.6.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.7.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.5.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.4.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.12.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.13.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.39.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.11.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.10.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.38.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.14.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.28.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.29.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.15.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.17.jpg
#   inflating: beans/test/bean_rust/bean_rust_test.16.jpg
# Archive:  validation.zip
#    creating: beans/validation/
#    creating: beans/validation/healthy/
#    creating: beans/validation/angular_leaf_spot/
#    creating: beans/validation/bean_rust/
#   inflating: beans/validation/healthy/healthy_val.6.jpg
#   inflating: beans/validation/healthy/healthy_val.7.jpg
#   inflating: beans/validation/healthy/healthy_val.5.jpg
#   inflating: beans/validation/healthy/healthy_val.4.jpg
#   inflating: beans/validation/healthy/healthy_val.0.jpg
#   inflating: beans/validation/healthy/healthy_val.1.jpg
#   inflating: beans/validation/healthy/healthy_val.3.jpg
#   inflating: beans/validation/healthy/healthy_val.2.jpg
#   inflating: beans/validation/healthy/healthy_val.14.jpg
#   inflating: beans/validation/healthy/healthy_val.28.jpg
#   inflating: beans/validation/healthy/healthy_val.29.jpg
#   inflating: beans/validation/healthy/healthy_val.15.jpg
#   inflating: beans/validation/healthy/healthy_val.17.jpg
#   inflating: beans/validation/healthy/healthy_val.16.jpg
#   inflating: beans/validation/healthy/healthy_val.12.jpg
#   inflating: beans/validation/healthy/healthy_val.13.jpg
#   inflating: beans/validation/healthy/healthy_val.39.jpg
#   inflating: beans/validation/healthy/healthy_val.11.jpg
#   inflating: beans/validation/healthy/healthy_val.10.jpg
#   inflating: beans/validation/healthy/healthy_val.38.jpg
#   inflating: beans/validation/healthy/healthy_val.35.jpg
#   inflating: beans/validation/healthy/healthy_val.21.jpg
#   inflating: beans/validation/healthy/healthy_val.20.jpg
#   inflating: beans/validation/healthy/healthy_val.34.jpg
#   inflating: beans/validation/healthy/healthy_val.22.jpg
#   inflating: beans/validation/healthy/healthy_val.36.jpg
#   inflating: beans/validation/healthy/healthy_val.37.jpg
#   inflating: beans/validation/healthy/healthy_val.23.jpg
#   inflating: beans/validation/healthy/healthy_val.27.jpg
#   inflating: beans/validation/healthy/healthy_val.33.jpg
#   inflating: beans/validation/healthy/healthy_val.32.jpg
#   inflating: beans/validation/healthy/healthy_val.26.jpg
#   inflating: beans/validation/healthy/healthy_val.18.jpg
#   inflating: beans/validation/healthy/healthy_val.30.jpg
#   inflating: beans/validation/healthy/healthy_val.24.jpg
#   inflating: beans/validation/healthy/healthy_val.25.jpg
#   inflating: beans/validation/healthy/healthy_val.31.jpg
#   inflating: beans/validation/healthy/healthy_val.19.jpg
#   inflating: beans/validation/healthy/healthy_val.42.jpg
#   inflating: beans/validation/healthy/healthy_val.43.jpg
#   inflating: beans/validation/healthy/healthy_val.41.jpg
#   inflating: beans/validation/healthy/healthy_val.40.jpg
#   inflating: beans/validation/healthy/healthy_val.9.jpg
#   inflating: beans/validation/healthy/healthy_val.8.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.37.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.23.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.22.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.36.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.20.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.34.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.35.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.21.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.25.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.31.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.19.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.18.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.30.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.24.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.32.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.26.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.27.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.33.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.40.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.1.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.0.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.41.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.43.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.2.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.3.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.42.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.7.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.6.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.4.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.5.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.8.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.9.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.16.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.17.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.29.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.15.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.14.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.28.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.10.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.38.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.39.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.11.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.13.jpg
#   inflating: beans/validation/angular_leaf_spot/angular_leaf_spot_val.12.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.13.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.12.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.38.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.10.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.11.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.39.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.8.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.15.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.29.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.28.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.14.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.9.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.16.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.17.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.44.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.43.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.42.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.40.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.41.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.7.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.26.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.32.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.33.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.27.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.6.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.4.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.19.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.31.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.25.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.24.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.30.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.18.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.5.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.1.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.34.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.20.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.21.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.35.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.0.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.2.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.23.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.37.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.36.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.22.jpg
#   inflating: beans/validation/bean_rust/bean_rust_val.3.jpg

# %%
# !ls beans
# Out:
# test  train  validation

# %%
# !ls beans/train
# Out:
# angular_leaf_spot  bean_rust  healthy

# %%
# !find beans -type f | wc -l
# Out:
# 1296

# %%
# !find beans/test -type f | wc -l
# Out:
# 128

# %%
# !find beans/validation -type f | wc -l
# Out:
# 133

# %%
# !ls beans/train/healthy
# Out:
# healthy_train.0.jpg    healthy_train.202.jpg  healthy_train.305.jpg
# healthy_train.100.jpg  healthy_train.203.jpg  healthy_train.306.jpg
# healthy_train.101.jpg  healthy_train.204.jpg  healthy_train.307.jpg
# healthy_train.102.jpg  healthy_train.205.jpg  healthy_train.308.jpg
# healthy_train.103.jpg  healthy_train.206.jpg  healthy_train.309.jpg
# healthy_train.104.jpg  healthy_train.207.jpg  healthy_train.30.jpg
# healthy_train.105.jpg  healthy_train.208.jpg  healthy_train.310.jpg
# healthy_train.106.jpg  healthy_train.209.jpg  healthy_train.311.jpg
# healthy_train.107.jpg  healthy_train.20.jpg   healthy_train.312.jpg
# healthy_train.108.jpg  healthy_train.210.jpg  healthy_train.313.jpg
# healthy_train.109.jpg  healthy_train.211.jpg  healthy_train.314.jpg
# healthy_train.10.jpg   healthy_train.212.jpg  healthy_train.315.jpg
# healthy_train.110.jpg  healthy_train.213.jpg  healthy_train.316.jpg
# healthy_train.111.jpg  healthy_train.214.jpg  healthy_train.317.jpg
# healthy_train.112.jpg  healthy_train.215.jpg  healthy_train.318.jpg
# healthy_train.113.jpg  healthy_train.216.jpg  healthy_train.319.jpg
# healthy_train.151.jpg  healthy_train.254.jpg  healthy_train.49.jpg
# healthy_train.152.jpg  healthy_train.255.jpg  healthy_train.4.jpg
# healthy_train.153.jpg  healthy_train.256.jpg  healthy_train.50.jpg
# healthy_train.154.jpg  healthy_train.257.jpg  healthy_train.51.jpg
# healthy_train.155.jpg  healthy_train.258.jpg  healthy_train.52.jpg
# healthy_train.156.jpg  healthy_train.259.jpg  healthy_train.53.jpg
# healthy_train.157.jpg  healthy_train.25.jpg   healthy_train.54.jpg
# healthy_train.158.jpg  healthy_train.260.jpg  healthy_train.55.jpg
# healthy_train.159.jpg  healthy_train.261.jpg  healthy_train.56.jpg
# healthy_train.15.jpg   healthy_train.262.jpg  healthy_train.57.jpg
# healthy_train.160.jpg  healthy_train.263.jpg  healthy_train.58.jpg
# healthy_train.161.jpg  healthy_train.264.jpg  healthy_train.59.jpg
# healthy_train.162.jpg  healthy_train.265.jpg  healthy_train.5.jpg
# healthy_train.163.jpg  healthy_train.266.jpg  healthy_train.60.jpg
# healthy_train.164.jpg  healthy_train.267.jpg  healthy_train.61.jpg
# healthy_train.165.jpg  healthy_train.268.jpg  healthy_train.62.jpg
# healthy_train.166.jpg  healthy_train.269.jpg  healthy_train.63.jpg
# healthy_train.167.jpg  healthy_train.26.jpg   healthy_train.64.jpg
# healthy_train.168.jpg  healthy_train.270.jpg  healthy_train.65.jpg
# healthy_train.169.jpg  healthy_train.271.jpg  healthy_train.66.jpg
# healthy_train.16.jpg   healthy_train.272.jpg  healthy_train.67.jpg
# healthy_train.170.jpg  healthy_train.273.jpg  healthy_train.68.jpg
# healthy_train.171.jpg  healthy_train.274.jpg  healthy_train.69.jpg
# healthy_train.172.jpg  healthy_train.275.jpg  healthy_train.6.jpg
# healthy_train.173.jpg  healthy_train.276.jpg  healthy_train.70.jpg
# healthy_train.174.jpg  healthy_train.277.jpg  healthy_train.71.jpg
# healthy_train.175.jpg  healthy_train.278.jpg  healthy_train.72.jpg
# healthy_train.176.jpg  healthy_train.279.jpg  healthy_train.73.jpg
# healthy_train.177.jpg  healthy_train.27.jpg   healthy_train.74.jpg
# healthy_train.178.jpg  healthy_train.280.jpg  healthy_train.75.jpg
# healthy_train.179.jpg  healthy_train.281.jpg  healthy_train.76.jpg
# healthy_train.17.jpg   healthy_train.282.jpg  healthy_train.77.jpg
# healthy_train.180.jpg  healthy_train.283.jpg  healthy_train.78.jpg
# healthy_train.181.jpg  healthy_train.284.jpg  healthy_train.79.jpg
# healthy_train.182.jpg  healthy_train.285.jpg  healthy_train.7.jpg
# healthy_train.183.jpg  healthy_train.286.jpg  healthy_train.80.jpg
# healthy_train.184.jpg  healthy_train.287.jpg  healthy_train.81.jpg
# healthy_train.185.jpg  healthy_train.288.jpg  healthy_train.82.jpg
# healthy_train.186.jpg  healthy_train.289.jpg  healthy_train.83.jpg
# healthy_train.187.jpg  healthy_train.28.jpg   healthy_train.84.jpg
# healthy_train.188.jpg  healthy_train.290.jpg  healthy_train.85.jpg
# healthy_train.189.jpg  healthy_train.291.jpg  healthy_train.86.jpg
# healthy_train.18.jpg   healthy_train.292.jpg  healthy_train.87.jpg
# healthy_train.190.jpg  healthy_train.293.jpg  healthy_train.88.jpg
# healthy_train.191.jpg  healthy_train.294.jpg  healthy_train.89.jpg
# healthy_train.192.jpg  healthy_train.295.jpg  healthy_train.8.jpg
# healthy_train.193.jpg  healthy_train.296.jpg  healthy_train.90.jpg
# healthy_train.194.jpg  healthy_train.297.jpg  healthy_train.91.jpg
# healthy_train.195.jpg  healthy_train.298.jpg  healthy_train.92.jpg
# healthy_train.196.jpg  healthy_train.299.jpg  healthy_train.93.jpg
# healthy_train.197.jpg  healthy_train.29.jpg   healthy_train.94.jpg
# healthy_train.198.jpg  healthy_train.2.jpg    healthy_train.95.jpg
# healthy_train.199.jpg  healthy_train.300.jpg  healthy_train.96.jpg
# healthy_train.19.jpg   healthy_train.301.jpg  healthy_train.97.jpg
# healthy_train.1.jpg    healthy_train.302.jpg  healthy_train.98.jpg
# healthy_train.200.jpg  healthy_train.303.jpg  healthy_train.99.jpg
# healthy_train.201.jpg  healthy_train.304.jpg  healthy_train.9.jpg

# %%
display(Image('beans/train/healthy/healthy_train.0.jpg'))

# %%
display(Image('beans/train/angular_leaf_spot/angular_leaf_spot_train.124.jpg'))

# %%
display(Image('beans/train/bean_rust/bean_rust_train.162.jpg'))

# %% [markdown]
# Setting up parameters

# %%
batch_size= 128
img_height = 224
img_width = 224

#Will be using MobileNetV2 model and hence seeting dim to 224*224

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory('beans/train',
                                                               seed=111,
                                                               image_size=(img_height,img_width),
                                                               batch_size=batch_size)
# Out:
# Found 1034 files belonging to 3 classes.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory('beans/test',
                                                               seed=111,
                                                               image_size=(img_height,img_width),
                                                               batch_size=batch_size)
# Out:
# Found 128 files belonging to 3 classes.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory('beans/validation',
                                                               seed=111,
                                                               image_size=(img_height,img_width),
                                                               batch_size=batch_size)
# Out:
# Found 133 files belonging to 3 classes.

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (128, 224, 224, 3)
# (128,)

# %%
classes = train_ds.class_names
classes
# Out:
# ['angular_leaf_spot', 'bean_rust', 'healthy']

# %%
plt.figure(figsize=(10,10))
for image,labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(image[i].numpy().astype("uint8"))
    plt.title(classes[labels[i]])
    plt.axis('off')

#take - 1 batch

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

#Autotune - Based on GPU and memory availability it autotunes
#We might want to prefetch the data in buffer for faster model training as we are using GPU
#Data is stored in cache and serialized to GPU based on buffer size

# %%
feature_extractor = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

# %%
feature_extractor_layer = hub.KerasLayer(feature_extractor,input_shape = (img_height, img_width, 3))

# %%
feature_extractor_layer.trainable= False

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

#since tf 2.4 preprocessing is a part of model graph itself. In Prior versions we create a preprocessing function 
# and deploy the function.

# %%
tf.random.set_seed(111)

# %%
model = tf.keras.Sequential([
    normalization_layer,
    feature_extractor_layer,
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(3, activation='softmax')

])

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)


# Since we are not one hot encoding we are using sparsecategoricalcrosEntropy if not we would use crossEntropy

# %%
history = model.fit(train_ds, epochs=5, validation_data= val_ds)
# Out:
# Epoch 1/5
# 9/9 [==============================] - 34s 4s/step - loss: 0.5172 - accuracy: 0.7805 - val_loss: 0.4498 - val_accuracy: 0.7970
# Epoch 2/5
# 9/9 [==============================] - 33s 4s/step - loss: 0.4727 - accuracy: 0.8046 - val_loss: 0.4174 - val_accuracy: 0.7895
# Epoch 3/5
# 9/9 [==============================] - 34s 4s/step - loss: 0.4264 - accuracy: 0.8308 - val_loss: 0.3944 - val_accuracy: 0.8195
# Epoch 4/5
# 9/9 [==============================] - 33s 4s/step - loss: 0.3906 - accuracy: 0.8414 - val_loss: 0.3700 - val_accuracy: 0.8571
# Epoch 5/5
# 9/9 [==============================] - 35s 4s/step - loss: 0.3767 - accuracy: 0.8472 - val_loss: 0.3540 - val_accuracy: 0.8872

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_acc','val_acc'],loc='best')
plt.show()

# %%
result = model.evaluate(test_ds)
# Out:
# 1/1 [==============================] - 8s 8s/step - loss: 0.3464 - accuracy: 0.8672

# %%
plt.figure(figsize=(12,12))
for images, labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)

    img = tf.keras.preprocessing.image.img_to_array(images[i])
    img = np.expand_dims(img,axis=0)

    pred = model.predict(img)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title("Actual label: %s" % classes[labels[i]])
    plt.text(1,240,"Predicted label: %s" % classes[np.argmax(pred)],fontsize=12)

    plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 128ms/step

# %%
model.save('./models',save_format='tf')

# %%
# !ls -alrt models
# Out:
# total 1888
# drwxr-xr-x 1 root root    4096 Jan  1 00:10 ..
# drwxr-xr-x 2 root root    4096 Jan  1 00:10 variables
# drwxr-xr-x 2 root root    4096 Jan  1 00:10 assets
# -rw-r--r-- 1 root root 1906532 Jan  1 00:10 saved_model.pb
# -rw-r--r-- 1 root root    6938 Jan  1 00:10 keras_metadata.pb
# drwxr-xr-x 4 root root    4096 Jan  1 00:10 .

# %%
model_loaded = tf.keras.models.load_model('./models/')

# %%
model_loaded.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
from PIL import Image
import numpy as np
from skimage import transform

def process(filename):
  np_image = Image.open(filename)
  np_image = np.array(np_image).astype('float32')
  np_image = transform.resize(np_image,(224,224,3))
  np_image = np.expand_dims(np_image,axis=0)
  return np_image

# %%
pred_label = model_loaded.predict(process('beans/train/healthy/healthy_train.0.jpg'))
print(classes[np.argmax(pred_label)])
# Out:
# 1/1 [==============================] - 1s 664ms/step
# healthy

# %%
pred_label
# Out:
# array([[0.00358995, 0.0649487 , 0.9314614 ]], dtype=float32)

# %%
# !zip -r models.zip models/
# Out:
#   adding: models/ (stored 0%)
#   adding: models/variables/ (stored 0%)
#   adding: models/variables/variables.index (deflated 78%)
#   adding: models/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: models/saved_model.pb (deflated 91%)
#   adding: models/assets/ (stored 0%)
#   adding: models/keras_metadata.pb (deflated 82%)

# %%
print(tf.__version__)
# Out:
# 2.9.2
